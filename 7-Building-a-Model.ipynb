# %% [markdown]
# # Building a Model in Python
#
# ---

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv("data/Melbourne_housing_FULL.csv")
df
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# 1             Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0
# 2             Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0
# 3             Rounds   4/02/2016       2.5    3067.0  ...       2.0  1.0
# 4             Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0
# ...              ...         ...       ...       ...  ...       ...  ...
# 34852            Jas  24/02/2018       6.3    3013.0  ...       1.0  3.0
# 34853        Sweeney  24/02/2018       6.3    3013.0  ...       2.0  1.0
# 34854            Jas  24/02/2018       6.3    3013.0  ...       1.0  2.0
# 34855  hockingstuart  24/02/2018       6.3    3013.0  ...       NaN  NaN
# 34856             RW  24/02/2018       6.3    3013.0  ...       1.0  0.0
#
#        Landsize  BuildingArea  YearBuilt               CouncilArea Lattitude  \
# 0         126.0           NaN        NaN        Yarra City Council -37.80140
# 1         202.0           NaN        NaN        Yarra City Council -37.79960
# 2         156.0          79.0     1900.0        Yarra City Council -37.80790
# 3           0.0           NaN        NaN        Yarra City Council -37.81140
# 4         134.0         150.0     1900.0        Yarra City Council -37.80930
# ...         ...           ...        ...                       ...       ...
# 34852     593.0           NaN        NaN  Maribyrnong City Council -37.81053
# 34853      98.0         104.0     2018.0  Maribyrnong City Council -37.81551
# 34854     220.0         120.0     2000.0  Maribyrnong City Council -37.82286
# 34855       NaN           NaN        NaN  Maribyrnong City Council       NaN
# 34856     250.0         103.0     1930.0  Maribyrnong City Council -37.81810
#
#        Longtitude             Regionname Propertycount
# 0       144.99580  Northern Metropolitan        4019.0
# 1       144.99840  Northern Metropolitan        4019.0
# 2       144.99340  Northern Metropolitan        4019.0
# 3       145.01160  Northern Metropolitan        4019.0
# 4       144.99440  Northern Metropolitan        4019.0
# ...           ...                    ...           ...
# 34852   144.88467   Western Metropolitan        6543.0
# 34853   144.88826   Western Metropolitan        6543.0
# 34854   144.87856   Western Metropolitan        6543.0
# 34855         NaN   Western Metropolitan        6543.0
# 34856   144.89351   Western Metropolitan        6543.0
#
# [34857 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
#  17  Lattitude      26881 non-null  float64
#  18  Longtitude     26881 non-null  float64
#  19  Regionname     34854 non-null  object
#  20  Propertycount  34854 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 5.6+ MB

# %% [markdown]
# > **Note: Price values in this dataset are expressed in Australian Dollars - \\$1 AUD is approximately \\$0.77 USD (2017).**

# %% [markdown]
# ## Data Cleaning

# %%
# Fix some of the column names
df.columns = ['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
       'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
       'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Latitude',
       'Longitude', 'Regionname', 'Propertycount']

# %%
df.sample(5)
# Out:
#                 Suburb            Address  Rooms Type      Price Method  \
# 20127   Mount Waverley      18 Jeffrey St      3    h        NaN     SN
# 15531  Caulfield South     2/203 North Rd      3    t  1237000.0      S
# 29081        Southbank   1603/8 Dorcas St      2    u   585000.0      S
# 17216      Pascoe Vale  3/15 Callander Rd      2    t        NaN     SN
# 6767       Middle Park  8/49 Patterson St      2    u   702000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 20127    Biggin   3/09/2017      14.2    3149.0  ...       1.0  2.0     790.0
# 15531      Gary  17/06/2017       8.7    3162.0  ...       2.0  2.0       0.0
# 29081        RT  25/11/2017       0.7    3006.0  ...       NaN  NaN       NaN
# 17216     Eview  27/05/2017       8.5    3044.0  ...       NaN  NaN       NaN
# 6767   Marshall  18/06/2016       4.1    3206.0  ...       1.0  1.0       0.0
#
#        BuildingArea  YearBuilt                CouncilArea  Latitude  \
# 20127         157.0     1970.0        Monash City Council -37.88883
# 15531         135.0     1990.0     Glen Eira City Council -37.90034
# 29081           NaN        NaN     Melbourne City Council       NaN
# 17216           NaN        NaN      Moreland City Council       NaN
# 6767            NaN     1970.0  Port Phillip City Council -37.85490
#
#        Longitude             Regionname Propertycount
# 20127  145.13684   Eastern Metropolitan       13366.0
# 15531  145.01283  Southern Metropolitan        5051.0
# 29081        NaN  Southern Metropolitan        8400.0
# 17216        NaN  Northern Metropolitan        7485.0
# 6767   144.96620  Southern Metropolitan        2019.0
#
# [5 rows x 21 columns]

# %%
# Drop unnecessary columns for building the model
df.drop(columns=['Address', 'Method', 'SellerG', 'Date', 'Postcode', 'Latitude',
                 'Longitude', 'Regionname', 'Propertycount'], inplace=True)
df
# Out:
#            Suburb  Rooms Type      Price  Distance  Bedroom2  Bathroom  Car  \
# 0      Abbotsford      2    h        NaN       2.5       2.0       1.0  1.0
# 1      Abbotsford      2    h  1480000.0       2.5       2.0       1.0  1.0
# 2      Abbotsford      2    h  1035000.0       2.5       2.0       1.0  0.0
# 3      Abbotsford      3    u        NaN       2.5       3.0       2.0  1.0
# 4      Abbotsford      3    h  1465000.0       2.5       3.0       2.0  0.0
# ...           ...    ...  ...        ...       ...       ...       ...  ...
# 34852  Yarraville      4    h  1480000.0       6.3       4.0       1.0  3.0
# 34853  Yarraville      2    h   888000.0       6.3       2.0       2.0  1.0
# 34854  Yarraville      2    t   705000.0       6.3       2.0       1.0  2.0
# 34855  Yarraville      3    h  1140000.0       6.3       NaN       NaN  NaN
# 34856  Yarraville      2    h  1020000.0       6.3       2.0       1.0  0.0
#
#        Landsize  BuildingArea  YearBuilt               CouncilArea
# 0         126.0           NaN        NaN        Yarra City Council
# 1         202.0           NaN        NaN        Yarra City Council
# 2         156.0          79.0     1900.0        Yarra City Council
# 3           0.0           NaN        NaN        Yarra City Council
# 4         134.0         150.0     1900.0        Yarra City Council
# ...         ...           ...        ...                       ...
# 34852     593.0           NaN        NaN  Maribyrnong City Council
# 34853      98.0         104.0     2018.0  Maribyrnong City Council
# 34854     220.0         120.0     2000.0  Maribyrnong City Council
# 34855       NaN           NaN        NaN  Maribyrnong City Council
# 34856     250.0         103.0     1930.0  Maribyrnong City Council
#
# [34857 rows x 12 columns]

# %% [markdown]
# ### Missing Values

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Price            7610
# Distance            1
# Bedroom2         8217
# Bathroom         8226
# Car              8728
# Landsize        11810
# BuildingArea    21115
# YearBuilt       19306
# CouncilArea         3
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)
df
# Out:
#            Suburb  Rooms Type      Price  Distance  Bedroom2  Bathroom  Car  \
# 2      Abbotsford      2    h  1035000.0       2.5       2.0       1.0  0.0
# 4      Abbotsford      3    h  1465000.0       2.5       3.0       2.0  0.0
# 6      Abbotsford      4    h  1600000.0       2.5       3.0       1.0  2.0
# 11     Abbotsford      3    h  1876000.0       2.5       4.0       2.0  0.0
# 14     Abbotsford      2    h  1636000.0       2.5       2.0       1.0  2.0
# ...           ...    ...  ...        ...       ...       ...       ...  ...
# 34847     Wollert      3    h   500000.0      25.5       3.0       2.0  2.0
# 34849     Wollert      3    h   570000.0      25.5       3.0       2.0  2.0
# 34853  Yarraville      2    h   888000.0       6.3       2.0       2.0  1.0
# 34854  Yarraville      2    t   705000.0       6.3       2.0       1.0  2.0
# 34856  Yarraville      2    h  1020000.0       6.3       2.0       1.0  0.0
#
#        Landsize  BuildingArea  YearBuilt               CouncilArea
# 2         156.0          79.0     1900.0        Yarra City Council
# 4         134.0         150.0     1900.0        Yarra City Council
# 6         120.0         142.0     2014.0        Yarra City Council
# 11        245.0         210.0     1910.0        Yarra City Council
# 14        256.0         107.0     1890.0        Yarra City Council
# ...         ...           ...        ...                       ...
# 34847     383.0         118.0     2016.0   Whittlesea City Council
# 34849     404.0         158.0     2012.0   Whittlesea City Council
# 34853      98.0         104.0     2018.0  Maribyrnong City Council
# 34854     220.0         120.0     2000.0  Maribyrnong City Council
# 34856     250.0         103.0     1930.0  Maribyrnong City Council
#
# [8895 rows x 12 columns]

# %% [markdown]
# ### Categorical features

# %%
df = pd.get_dummies(df, columns=['Suburb', 'Type', 'CouncilArea'], dtype=int)
df
# Out:
#        Rooms      Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 2          2  1035000.0       2.5       2.0       1.0  0.0     156.0
# 4          3  1465000.0       2.5       3.0       2.0  0.0     134.0
# 6          4  1600000.0       2.5       3.0       1.0  2.0     120.0
# 11         3  1876000.0       2.5       4.0       2.0  0.0     245.0
# 14         2  1636000.0       2.5       2.0       1.0  2.0     256.0
# ...      ...        ...       ...       ...       ...  ...       ...
# 34847      3   500000.0      25.5       3.0       2.0  2.0     383.0
# 34849      3   570000.0      25.5       3.0       2.0  2.0     404.0
# 34853      2   888000.0       6.3       2.0       2.0  1.0      98.0
# 34854      2   705000.0       6.3       2.0       1.0  2.0     220.0
# 34856      2  1020000.0       6.3       2.0       1.0  0.0     250.0
#
#        BuildingArea  YearBuilt  Suburb_Abbotsford  ...  \
# 2              79.0     1900.0                  1  ...
# 4             150.0     1900.0                  1  ...
# 6             142.0     2014.0                  1  ...
# 11            210.0     1910.0                  1  ...
# 14            107.0     1890.0                  1  ...
# ...             ...        ...                ...  ...
# 34847         118.0     2016.0                  0  ...
# 34849         158.0     2012.0                  0  ...
# 34853         104.0     2018.0                  0  ...
# 34854         120.0     2000.0                  0  ...
# 34856         103.0     1930.0                  0  ...
#
#        CouncilArea_Moorabool Shire Council  CouncilArea_Moreland City Council  \
# 2                                        0                                  0
# 4                                        0                                  0
# 6                                        0                                  0
# 11                                       0                                  0
# 14                                       0                                  0
# ...                                    ...                                ...
# 34847                                    0                                  0
# 34849                                    0                                  0
# 34853                                    0                                  0
# 34854                                    0                                  0
# 34856                                    0                                  0
#
#        CouncilArea_Nillumbik Shire Council  \
# 2                                        0
# 4                                        0
# 6                                        0
# 11                                       0
# 14                                       0
# ...                                    ...
# 34847                                    0
# 34849                                    0
# 34853                                    0
# 34854                                    0
# 34856                                    0
#
#        CouncilArea_Port Phillip City Council  \
# 2                                          0
# 4                                          0
# 6                                          0
# 11                                         0
# 14                                         0
# ...                                      ...
# 34847                                      0
# 34849                                      0
# 34853                                      0
# 34854                                      0
# 34856                                      0
#
#        CouncilArea_Stonnington City Council  \
# 2                                         0
# 4                                         0
# 6                                         0
# 11                                        0
# 14                                        0
# ...                                     ...
# 34847                                     0
# 34849                                     0
# 34853                                     0
# 34854                                     0
# 34856                                     0
#
#        CouncilArea_Whitehorse City Council  \
# 2                                        0
# 4                                        0
# 6                                        0
# 11                                       0
# 14                                       0
# ...                                    ...
# 34847                                    0
# 34849                                    0
# 34853                                    0
# 34854                                    0
# 34856                                    0
#
#        CouncilArea_Whittlesea City Council  CouncilArea_Wyndham City Council  \
# 2                                        0                                 0
# 4                                        0                                 0
# 6                                        0                                 0
# 11                                       0                                 0
# 14                                       0                                 0
# ...                                    ...                               ...
# 34847                                    1                                 0
# 34849                                    1                                 0
# 34853                                    0                                 0
# 34854                                    0                                 0
# 34856                                    0                                 0
#
#        CouncilArea_Yarra City Council  CouncilArea_Yarra Ranges Shire Council
# 2                                   1                                       0
# 4                                   1                                       0
# 6                                   1                                       0
# 11                                  1                                       0
# 14                                  1                                       0
# ...                               ...                                     ...
# 34847                               0                                       0
# 34849                               0                                       0
# 34853                               0                                       0
# 34854                               0                                       0
# 34856                               0                                       0
#
# [8895 rows x 360 columns]

# %% [markdown]
# ## Split the Dataset

# %%
X = df.drop('Price', axis=1)
y = df['Price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=True)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((6226, 359), (2669, 359), (6226,), (2669,))

# %% [markdown]
# ## Select Algorithm and Configure Hyperparameters

# %%
model = GradientBoostingRegressor(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=5,
    min_samples_split=4,
    min_samples_leaf=5,
    max_features=0.6,
    loss='huber'
)

model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(loss='huber', max_depth=5, max_features=0.6,
#                           min_samples_leaf=5, min_samples_split=4,
#                           n_estimators=200)

# %% [markdown]
# ## Evaluate the Results

# %%
y_pred_train = model.predict(X_train)
mae_train = mean_absolute_error(y_train, y_pred_train)
print(f"Train Set MAE: {mae_train:.2f}")

y_pred_test = model.predict(X_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
print(f"Test Set MAE: {mae_test:.2f}")
# Out:
# Train Set MAE: 126689.09
# Test Set MAE: 160807.30

# %% [markdown]
# # Model Optimization

# %%
# Input algorithm
model = GradientBoostingRegressor()

# Set the configurations that you wish to test.
hyperparameters = {
    'n_estimators':[200, 300],
    'max_depth':[4, 6],
    'min_samples_split':[3, 4],
    'min_samples_leaf':[5, 6],
    'learning_rate':[0.01, 0.02],
    'max_features':[0.8, 0.9],
    'loss':['ls', 'lad', 'huber']
}

# Define grid search.
grid = GridSearchCV(model, hyperparameters, n_jobs=4)

# Run grid search on training data
grid.fit(X_train, y_train)

# Return optimal hyperparameters
grid.best_params_
# Out:
# C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 640 fits failed out of a total of 960.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 250 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingRegressor must be a str among {'absolute_error', 'huber', 'quantile', 'squared_error'}. Got 'ls' instead.
#
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingRegressor must be a str among {'quantile', 'huber', 'absolute_error', 'squared_error'}. Got 'ls' instead.
#
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingRegressor must be a str among {'absolute_error', 'squared_error', 'quantile', 'huber'}. Got 'ls' instead.
#
# --------------------------------------------------------------------------------
# 224 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingRegressor must be a str among {'absolute_error', 'huber', 'quantile', 'squared_error'}. Got 'lad' instead.
#
# --------------------------------------------------------------------------------
# 48 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingRegressor must be a str among {'quantile', 'huber', 'absolute_error', 'squared_error'}. Got 'lad' instead.
#
# --------------------------------------------------------------------------------
# 48 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingRegressor must be a str among {'absolute_error', 'squared_error', 'quantile', 'huber'}. Got 'lad' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\JAVOHIR\miniconda3\envs\mohirdsai\lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.62215947 0.68938281
#  0.62271699 0.69082034 0.6227275  0.69089659 0.62250178 0.69055254
#  0.62255701 0.69123999 0.62287417 0.69112674 0.62435629 0.69199997
#  0.62340022 0.69185486 0.69599824 0.75300487 0.69551444 0.75239101
#  0.69681536 0.75252409 0.69591795 0.75320055 0.69421283 0.75200749
#  0.69439645 0.7524913  0.69514819 0.75170549 0.69501004 0.75236555
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.72174422 0.75548823
#  0.72094317 0.75602761 0.72300286 0.75659358 0.72280435 0.75749975
#  0.72272627 0.7563791  0.72245487 0.75694593 0.72192924 0.75704003
#  0.72283635 0.756996   0.77505387 0.79695502 0.77514483 0.79441378
#  0.77581853 0.79447291 0.77604981 0.79436125 0.77495691 0.79362599
#  0.77470515 0.79360011 0.77445946 0.7920989  0.7749378  0.79230063]
#   warnings.warn(
# {'learning_rate': 0.02,
#  'loss': 'huber',
#  'max_depth': 6,
#  'max_features': 0.8,
#  'min_samples_leaf': 5,
#  'min_samples_split': 3,
#  'n_estimators': 300}

# %%
# Check model accuracy using optimal hyperparameters
mae_train = mean_absolute_error(y_train, grid.predict(X_train))
print(f"Train MAE: {mae_train:.2f}")

mae_test = mean_absolute_error(y_test, grid.predict(X_test))
print(f"Test MAE: {mae_test:.2f}")
# Out:
# Train MAE: 138226.82
# Test MAE: 168133.38
